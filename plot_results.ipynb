# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
exper_name = "ResNet56v2_origin"
log=pd.read_csv(f"./log/training.log.{exper_name}.csv")
class_weight = {0:1, 1:1}
class_indices = ["bad_1", "good_0"] # good_0 is the positive class
print(f"class_weight: {class_weight}.")
print(f"class_indices: {class_indices}.")
num_epochs = 150 # done
# Out:
# class_weight: {0: 1, 1: 1}.
# class_indices: ['bad_1', 'good_0'].

# %%
mpl.rcParams['figure.figsize'] = (8, 5)
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
filled_markers = ('o', 'v', '^', '<', '>', '8', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X')

# epoch,
# accuracy,
# auc_bad_1,
# false_negatives,
# false_negatives_1,
# loss
# true_negatives,
# true_negatives_1,
# val_accuracy,
# val_auc_bad_1,
# val_false_negatives,
# val_false_negatives_1,
# val_loss,
# val_true_negatives,
# val_true_negatives_1

# %%
log
# Out:
#      epoch  val_accuracy  auc_good_0  auc_bad_1
# 0      0.0        0.0000      0.9092     0.0000
# 1      1.0        0.9092      0.0000     0.0000
# 2      2.0        0.9092      0.0000     0.0000
# 3      3.0        0.0000      0.0000     0.0000
# 4      4.0        0.0000      0.0000     0.0000
# ..     ...           ...         ...        ...
# 145  145.0        0.0000      0.9886     0.9887
# 146  146.0        0.0000      0.9888     0.9887
# 147  147.0        0.0000      0.9885     0.9887
# 148  148.0        0.0000      0.9885     0.9886
# 149  149.0        0.0000      0.9882     0.9886
#
# [150 rows x 4 columns]

# %%
plt.plot(log["epoch"].values, log["auc_good_0"].values, color=cycle[1], marker=filled_markers[1], linewidth=1, markersize=2, label="auc_good_0")
# plt.xticks(np.arange(1,200,10))
# plt.xlim(70, 90)
# plt.xlim(80, 200)
# plt.ylim(0.15, 0.2)
# plt.ylim(-0.1, 1)
plt.legend()
plt.tight_layout()
plt.grid()

# %%
plt.plot(log["epoch"].values, log["auc_bad_1"].values, color=cycle[1], marker=filled_markers[1], linewidth=1, markersize=2, label="auc_bad_1")
# plt.xticks(np.arange(1,200,10))
# plt.xlim(70, 90)
# plt.xlim(80, 200)
# plt.ylim(0.15, 0.2)
# plt.ylim(-0.1, 1)
plt.legend()
plt.tight_layout()
plt.grid()
